# %%
import torch

# Modeli yükle (face2paint: Yüzleri animeye çevirir)
model = torch.hub.load('bryandlee/animegan2-pytorch:main', 'generator', device='cpu')
face2paint = torch.hub.load('bryandlee/animegan2-pytorch:main', 'face2paint', size=512, device='cpu')

from PIL import Image
import requests

# Bir fotoğraf indir
url = "/kaggle/input/ornekler/donoldTrump.jpg"
img = Image.open(url).convert("RGB")

# Dönüştür
out =face2paint(model, img)
out
# Out:
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2619, done.
# remote: Total 2619 (delta 0), reused 0 (delta 0), pack-reused 2619 (from 1)
# Receiving objects: 100% (2619/2619), 8.24 MiB | 13.47 MiB/s, done.
# Resolving deltas: 100% (1654/1654), done.

# %%
# !cd /kaggle/working/pytorch-CycleGAN-and-pix2pix

# %%
! ./pytorch-CycleGAN-and-pix2pix/scripts/download_cyclegan_model.sh horse2zebra
# Out:
#   File "/tmp/ipykernel_47/3935181015.py", line 1
#     ./pytorch-CycleGAN-and-pix2pix/scripts/download_cyclegan_model.sh horse2zebra
#     ^
# SyntaxError: invalid syntax
